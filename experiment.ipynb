# %%
import numpy as np
from utils import key_frame_detection, generate_scene_graph
from dataloader import read_bag, load_pickle
from llm_engine import NarrationEngine
from rosbags.typesys import Stores, get_typestore, get_types_from_msg
import pickle
import json
import matplotlib.pyplot as plt 
from os import listdir
from os.path import isfile, join

with open('config/constraints_summary.txt', 'r') as f:
    constraints = f.read()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <cell line: 3>()
#       1 import numpy as np
#       2 from utils import key_frame_detection, generate_scene_graph
# ----> 3 from dataloader import read_bag, load_pickle
#       4 from llm_engine import NarrationEngine
#       5 from rosbags.typesys import Stores, get_typestore, get_types_from_msg
#
# ModuleNotFoundError: No module named 'dataloader'

# %%
smach_container_status_msg = '''
std_msgs/Header header
string path
string[] initial_states
string[] active_states
uint8[] local_data
string info
'''

smach_container_structure_msg = '''
std_msgs/Header header
string path
string[] children
string[] internal_outcomes
string[] outcomes_from
string[] outcomes_to
string[] container_outcomes
'''

add_types = {}
add_types.update(get_types_from_msg(smach_container_status_msg, 'smach_msgs/msg/SmachContainerStatus'))
add_types.update(get_types_from_msg(smach_container_structure_msg, 'smach_msgs/msg/SmachContainerStructure'))

typestore = get_typestore(Stores.ROS2_HUMBLE)
typestore.register(add_types)

camera_info = {'cx': 385.22119140625,
               'cy': 640.2664794921875,
               'fx': 907.1741333007812,
               'fy': 907.033447265625}

# %%
task = 'cup'
vocab_cup = ['cup', 'table', 'chair', 'person', 'sofa', 'stool', 'coffee table', 'gripper', 'sink']
task_name = 'Pick and place the cup in the sink'
task_desc = 'The robot should navigate to the table with dirty cup on it, pick up the cup, find the sink, navigate to the sink and place the cup in the sink.'

task = 'microwave'
vocab_cup = ['microwave', 'table', 'chair', 'person', 'sofa', 'stool', 'microwave door', 'microwave handle', 'gripper', 'sink']
task_name = 'Microwave the lunchbox'
task_desc = ''

# %% [markdown]
# ### Load data

# %%
def vis(data):
    for keyframe in range(len(data['rgb'])):
        if log:
            print('frame:', keyframe)
            print('state:', data['state'][keyframe])
            print('state history:', data['state_history'][keyframe])
            print('odom:', data['odom'][keyframe])
            print('joint state:', data['joint_state'][keyframe])
            plt.imshow(data['rgb'][keyframe])

# %%
path = '../data/keyframes/keyframes_only/'+task+'/'
files = sorted([f for f in listdir(path) if isfile(join(path, f)) and '.pkl' in f])
print(len(files))
# Out:
# 32

# %% [markdown]
# ### RONAR

# %%
narr_engine = NarrationEngine(model='gpt-4o')

# %% [markdown]
# #### Env

# %%
for file_name in files:
    if '.json' not in file_name:
        print('File Name:', file_name)
        file_path = path + file_name
        data = load_pickle(file_path)
        data['camera_info'] = camera_info
        env_summary = []
        for i in range(len(data['rgb'])):
            print('Key Frame:', str(i))
            keyframe = {'rgb': data['rgb'][i], 
                        'depth': data['depth'][i], 
                        'odom': data['odom'][i], 
                        'joint_state': data['joint_state'][i], 
                        'camera_info': data['camera_info']}
            
            env_rgbd_summary = narr_engine.summarize_env_rgbd(keyframe, vocab_list=vocab_cup)
            env_summary.append(env_rgbd_summary)
        with open(file_path.replace('.pkl', '_env_sum_35_turbo.json'), 'w') as f:
            json.dump({'env_sum': env_summary}, f)
# Out:
# File Name: rosbag2_2024_05_15-01_44_42.pkl
# Key Frame: 0
#
# 0: 1280x704 2 chairs, 1 sofa, 22.9ms
# Speed: 3.1ms preprocess, 22.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 54 objects, 36.9ms
# Speed: 1.8ms preprocess, 36.9ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 54 objects, 36.7ms
# Speed: 1.9ms preprocess, 36.7ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 54 objects, 36.7ms
# Speed: 2.2ms preprocess, 36.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 1
#
# 0: 1280x704 2 chairs, 1 sofa, 1 coffee table, 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 52 objects, 36.7ms
# Speed: 1.8ms preprocess, 36.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 52 objects, 36.1ms
# Speed: 2.2ms preprocess, 36.1ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 52 objects, 35.2ms
# Speed: 2.2ms preprocess, 35.2ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 52 objects, 35.2ms
# Speed: 2.1ms preprocess, 35.2ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 2
#
# 0: 1280x704 5 chairs, 1 sofa, 1 stool, 1 coffee table, 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 60 objects, 36.7ms
# Speed: 1.8ms preprocess, 36.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 60 objects, 36.7ms
# Speed: 2.0ms preprocess, 36.7ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 60 objects, 35.3ms
# Speed: 2.3ms preprocess, 35.3ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 60 objects, 35.2ms
# Speed: 2.0ms preprocess, 35.2ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 60 objects, 35.5ms
# Speed: 1.9ms preprocess, 35.5ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 60 objects, 35.0ms
# Speed: 2.1ms preprocess, 35.0ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 60 objects, 35.0ms
# Speed: 1.9ms preprocess, 35.0ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 60 objects, 35.0ms
# Speed: 2.0ms preprocess, 35.0ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 3
#
# 0: 1280x704 5 chairs, 2 sofas, 1 stool, 1 coffee table, 22.9ms
# Speed: 1.9ms preprocess, 22.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 70 objects, 36.7ms
# Speed: 1.8ms preprocess, 36.7ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 70 objects, 36.7ms
# Speed: 2.0ms preprocess, 36.7ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 70 objects, 36.7ms
# Speed: 2.0ms preprocess, 36.7ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 70 objects, 36.7ms
# Speed: 2.1ms preprocess, 36.7ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 70 objects, 35.0ms
# Speed: 1.9ms preprocess, 35.0ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 70 objects, 35.0ms
# Speed: 1.9ms preprocess, 35.0ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 70 objects, 35.0ms
# Speed: 2.3ms preprocess, 35.0ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 70 objects, 35.0ms
# Speed: 2.0ms preprocess, 35.0ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 70 objects, 35.1ms
# Speed: 2.0ms preprocess, 35.1ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 4
#
# 0: 1280x704 2 chairs, 1 sofa, 22.9ms
# Speed: 1.9ms preprocess, 22.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 56 objects, 36.7ms
# Speed: 1.8ms preprocess, 36.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 56 objects, 36.7ms
# Speed: 1.9ms preprocess, 36.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 56 objects, 36.6ms
# Speed: 1.9ms preprocess, 36.6ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 5
#
# 0: 1280x704 3 chairs, 22.9ms
# Speed: 1.7ms preprocess, 22.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 37 objects, 36.6ms
# Speed: 1.8ms preprocess, 36.6ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 37 objects, 36.7ms
# Speed: 2.0ms preprocess, 36.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 37 objects, 35.0ms
# Speed: 2.0ms preprocess, 35.0ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 6
#
# 0: 1280x704 3 chairs, 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 28 objects, 36.7ms
# Speed: 1.8ms preprocess, 36.7ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 28 objects, 36.8ms
# Speed: 2.2ms preprocess, 36.8ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 28 objects, 35.8ms
# Speed: 2.1ms preprocess, 35.8ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 7
#
# 0: 1280x704 (no detections), 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.2ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 8
#
# 0: 1280x704 2 cups, 3 chairs, 2 sofas, 1 coffee table, 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 56 objects, 36.7ms
# Speed: 1.8ms preprocess, 36.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 56 objects, 36.7ms
# Speed: 1.9ms preprocess, 36.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 56 objects, 36.8ms
# Speed: 1.9ms preprocess, 36.8ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 56 objects, 35.2ms
# Speed: 1.9ms preprocess, 35.2ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 56 objects, 35.1ms
# Speed: 2.7ms preprocess, 35.1ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 56 objects, 35.2ms
# Speed: 1.9ms preprocess, 35.2ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 56 objects, 35.0ms
# Speed: 2.0ms preprocess, 35.0ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 56 objects, 35.0ms
# Speed: 2.1ms preprocess, 35.0ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 9
#
# 0: 1280x704 2 cups, 3 chairs, 2 sofas, 1 coffee table, 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 67 objects, 36.7ms
# Speed: 1.8ms preprocess, 36.7ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 67 objects, 36.7ms
# Speed: 2.0ms preprocess, 36.7ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 67 objects, 36.7ms
# Speed: 2.0ms preprocess, 36.7ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 67 objects, 36.7ms
# Speed: 1.9ms preprocess, 36.7ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 67 objects, 35.0ms
# Speed: 1.9ms preprocess, 35.0ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 67 objects, 35.0ms
# Speed: 2.0ms preprocess, 35.0ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 67 objects, 35.1ms
# Speed: 2.0ms preprocess, 35.1ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 67 objects, 35.1ms
# Speed: 1.9ms preprocess, 35.1ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 10
#
# 0: 1280x704 2 cups, 3 chairs, 2 sofas, 1 coffee table, 22.8ms
# Speed: 1.8ms preprocess, 22.8ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 76 objects, 36.7ms
# Speed: 1.8ms preprocess, 36.7ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 76 objects, 36.5ms
# Speed: 2.0ms preprocess, 36.5ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 76 objects, 35.1ms
# Speed: 2.1ms preprocess, 35.1ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 76 objects, 35.0ms
# Speed: 2.0ms preprocess, 35.0ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 76 objects, 35.0ms
# Speed: 2.0ms preprocess, 35.0ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 76 objects, 35.0ms
# Speed: 2.0ms preprocess, 35.0ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 76 objects, 35.1ms
# Speed: 2.0ms preprocess, 35.1ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 76 objects, 35.0ms
# Speed: 2.0ms preprocess, 35.0ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 11
#
# 0: 1280x704 1 cup, 3 chairs, 2 sofas, 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.6ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 59 objects, 36.7ms
# Speed: 1.9ms preprocess, 36.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 59 objects, 36.7ms
# Speed: 1.9ms preprocess, 36.7ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 59 objects, 36.8ms
# Speed: 1.9ms preprocess, 36.8ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 59 objects, 36.7ms
# Speed: 1.9ms preprocess, 36.7ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 59 objects, 35.1ms
# Speed: 1.9ms preprocess, 35.1ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 59 objects, 35.1ms
# Speed: 1.9ms preprocess, 35.1ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 12
#
# 0: 1280x704 3 chairs, 22.9ms
# Speed: 2.4ms preprocess, 22.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 32 objects, 36.7ms
# Speed: 1.8ms preprocess, 36.7ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 32 objects, 36.8ms
# Speed: 2.0ms preprocess, 36.8ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 32 objects, 36.7ms
# Speed: 2.0ms preprocess, 36.7ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 13
#
# 0: 1280x704 1 chair, 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 60 objects, 36.7ms
# Speed: 1.8ms preprocess, 36.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 14
#
# 0: 1280x704 1 chair, 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 58 objects, 36.7ms
# Speed: 1.9ms preprocess, 36.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 15
#
# 0: 1280x704 (no detections), 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.3ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 16
#
# 0: 1280x704 (no detections), 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.3ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 17
#
# 0: 1280x704 (no detections), 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.3ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 18
#
# 0: 1280x704 (no detections), 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.3ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 19
#
# 0: 1280x704 (no detections), 22.9ms
# Speed: 1.7ms preprocess, 22.9ms inference, 0.2ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 20
#
# 0: 1280x704 1 sink, 23.0ms
# Speed: 1.8ms preprocess, 23.0ms inference, 0.7ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 76 objects, 36.7ms
# Speed: 1.8ms preprocess, 36.7ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 21
#
# 0: 1280x704 (no detections), 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.2ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 22
#
# 0: 1280x704 1 chair, 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 52 objects, 36.8ms
# Speed: 1.8ms preprocess, 36.8ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 23
#
# 0: 1280x704 (no detections), 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.3ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 24
#
# 0: 1280x704 1 chair, 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 28 objects, 36.7ms
# Speed: 1.8ms preprocess, 36.7ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 25
#
# 0: 1280x704 1 chair, 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 29 objects, 36.7ms
# Speed: 1.7ms preprocess, 36.7ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 26
#
# 0: 1280x704 1 sink, 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 62 objects, 36.8ms
# Speed: 1.8ms preprocess, 36.8ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 27
#
# 0: 1280x704 1 sink, 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 78 objects, 36.7ms
# Speed: 1.8ms preprocess, 36.7ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 28
#
# 0: 1280x704 1 sink, 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 68 objects, 36.6ms
# Speed: 1.8ms preprocess, 36.6ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 29
#
# 0: 1280x704 1 cup, 1 sink, 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 65 objects, 36.7ms
# Speed: 1.8ms preprocess, 36.7ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 65 objects, 36.7ms
# Speed: 2.2ms preprocess, 36.7ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 30
#
# 0: 1280x704 1 cup, 1 sink, 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 78 objects, 36.7ms
# Speed: 1.8ms preprocess, 36.7ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 78 objects, 35.7ms
# Speed: 2.1ms preprocess, 35.7ms inference, 2.3ms postprocess per image at shape (1, 3, 1280, 704)
# File Name: rosbag2_2024_05_15-23_45_03.pkl
# Key Frame: 0
#
# 0: 1280x704 3 chairs, 1 sofa, 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.6ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 47 objects, 36.8ms
# Speed: 1.8ms preprocess, 36.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 47 objects, 36.4ms
# Speed: 2.2ms preprocess, 36.4ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 47 objects, 35.4ms
# Speed: 2.0ms preprocess, 35.4ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 47 objects, 35.4ms
# Speed: 1.9ms preprocess, 35.4ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 1
#
# 0: 1280x704 3 chairs, 1 sofa, 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 44 objects, 36.7ms
# Speed: 1.9ms preprocess, 36.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 44 objects, 36.8ms
# Speed: 2.0ms preprocess, 36.8ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 44 objects, 36.8ms
# Speed: 2.0ms preprocess, 36.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 44 objects, 36.3ms
# Speed: 2.0ms preprocess, 36.3ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 2
#
# 0: 1280x704 2 chairs, 2 sofas, 22.9ms
# Speed: 2.4ms preprocess, 22.9ms inference, 0.6ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 43 objects, 36.7ms
# Speed: 2.0ms preprocess, 36.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 43 objects, 35.7ms
# Speed: 1.9ms preprocess, 35.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 43 objects, 35.2ms
# Speed: 1.9ms preprocess, 35.2ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 43 objects, 35.5ms
# Speed: 2.0ms preprocess, 35.5ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 3
#
# 0: 1280x704 2 chairs, 1 coffee table, 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 55 objects, 36.7ms
# Speed: 1.8ms preprocess, 36.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 55 objects, 36.8ms
# Speed: 2.0ms preprocess, 36.8ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 55 objects, 36.8ms
# Speed: 2.0ms preprocess, 36.8ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 4
#
# 0: 1280x704 6 chairs, 1 sofa, 1 stool, 22.9ms
# Speed: 1.9ms preprocess, 22.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 56 objects, 36.7ms
# Speed: 1.8ms preprocess, 36.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 56 objects, 36.7ms
# Speed: 2.1ms preprocess, 36.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 56 objects, 36.3ms
# Speed: 2.1ms preprocess, 36.3ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 56 objects, 35.4ms
# Speed: 2.1ms preprocess, 35.4ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 56 objects, 35.4ms
# Speed: 2.1ms preprocess, 35.4ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 56 objects, 35.2ms
# Speed: 2.2ms preprocess, 35.2ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 56 objects, 35.2ms
# Speed: 2.1ms preprocess, 35.2ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 56 objects, 35.2ms
# Speed: 2.2ms preprocess, 35.2ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 5
#
# 0: 1280x704 1 chair, 2 sofas, 1 stool, 1 coffee table, 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 99 objects, 36.7ms
# Speed: 1.7ms preprocess, 36.7ms inference, 2.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 99 objects, 36.7ms
# Speed: 2.1ms preprocess, 36.7ms inference, 2.6ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 99 objects, 35.6ms
# Speed: 1.9ms preprocess, 35.6ms inference, 2.7ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 99 objects, 35.3ms
# Speed: 1.9ms preprocess, 35.3ms inference, 2.8ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 99 objects, 35.2ms
# Speed: 1.9ms preprocess, 35.2ms inference, 2.6ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 6
#
# 0: 1280x704 3 chairs, 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 39 objects, 36.7ms
# Speed: 1.8ms preprocess, 36.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 39 objects, 36.7ms
# Speed: 2.2ms preprocess, 36.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 39 objects, 36.7ms
# Speed: 2.1ms preprocess, 36.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 7
#
# 0: 1280x704 2 chairs, 22.8ms
# Speed: 1.8ms preprocess, 22.8ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 33 objects, 36.7ms
# Speed: 1.8ms preprocess, 36.7ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 33 objects, 36.8ms
# Speed: 2.2ms preprocess, 36.8ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 8
#
# 0: 1280x704 1 person, 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 42 objects, 36.7ms
# Speed: 1.8ms preprocess, 36.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 9
#
# 0: 1280x704 4 chairs, 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 38 objects, 36.7ms
# Speed: 1.7ms preprocess, 36.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 38 objects, 36.8ms
# Speed: 2.1ms preprocess, 36.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 38 objects, 36.7ms
# Speed: 2.1ms preprocess, 36.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 38 objects, 36.6ms
# Speed: 2.1ms preprocess, 36.6ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 10
#
# 0: 1280x704 1 cup, 3 chairs, 2 sofas, 3 stools, 1 coffee table, 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 62 objects, 36.7ms
# Speed: 1.8ms preprocess, 36.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 62 objects, 35.2ms
# Speed: 2.1ms preprocess, 35.2ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 62 objects, 35.2ms
# Speed: 2.1ms preprocess, 35.2ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 62 objects, 35.2ms
# Speed: 2.2ms preprocess, 35.2ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 62 objects, 35.2ms
# Speed: 2.1ms preprocess, 35.2ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 62 objects, 35.4ms
# Speed: 2.1ms preprocess, 35.4ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 62 objects, 35.1ms
# Speed: 2.2ms preprocess, 35.1ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 62 objects, 35.1ms
# Speed: 2.0ms preprocess, 35.1ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 62 objects, 35.0ms
# Speed: 2.2ms preprocess, 35.0ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 62 objects, 35.0ms
# Speed: 2.2ms preprocess, 35.0ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 11
#
# 0: 1280x704 1 cup, 4 chairs, 2 sofas, 2 stools, 2 coffee tables, 23.0ms
# Speed: 2.0ms preprocess, 23.0ms inference, 0.8ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 63 objects, 36.7ms
# Speed: 1.8ms preprocess, 36.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 63 objects, 35.7ms
# Speed: 1.9ms preprocess, 35.7ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 63 objects, 35.3ms
# Speed: 2.0ms preprocess, 35.3ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 63 objects, 35.2ms
# Speed: 1.9ms preprocess, 35.2ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 63 objects, 35.2ms
# Speed: 1.9ms preprocess, 35.2ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 63 objects, 35.2ms
# Speed: 1.9ms preprocess, 35.2ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 63 objects, 35.4ms
# Speed: 1.9ms preprocess, 35.4ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 63 objects, 35.4ms
# Speed: 1.9ms preprocess, 35.4ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 63 objects, 35.3ms
# Speed: 2.1ms preprocess, 35.3ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 63 objects, 35.2ms
# Speed: 2.1ms preprocess, 35.2ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 63 objects, 35.3ms
# Speed: 2.1ms preprocess, 35.3ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 12
#
# 0: 1280x704 1 cup, 5 chairs, 2 sofas, 1 coffee table, 22.9ms
# Speed: 1.7ms preprocess, 22.9ms inference, 0.6ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 78 objects, 36.7ms
# Speed: 1.8ms preprocess, 36.7ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 78 objects, 36.8ms
# Speed: 2.1ms preprocess, 36.8ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 78 objects, 36.8ms
# Speed: 2.0ms preprocess, 36.8ms inference, 2.3ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 78 objects, 35.9ms
# Speed: 2.1ms preprocess, 35.9ms inference, 2.3ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 78 objects, 35.2ms
# Speed: 2.0ms preprocess, 35.2ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 78 objects, 35.2ms
# Speed: 2.1ms preprocess, 35.2ms inference, 2.3ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 78 objects, 35.2ms
# Speed: 2.1ms preprocess, 35.2ms inference, 2.3ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 78 objects, 35.3ms
# Speed: 2.1ms preprocess, 35.3ms inference, 2.3ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 78 objects, 35.3ms
# Speed: 2.1ms preprocess, 35.3ms inference, 2.3ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 13
#
# 0: 1280x704 1 cup, 3 chairs, 2 sofas, 22.9ms
# Speed: 2.9ms preprocess, 22.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 75 objects, 36.6ms
# Speed: 1.8ms preprocess, 36.6ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 75 objects, 35.9ms
# Speed: 2.2ms preprocess, 35.9ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 75 objects, 35.2ms
# Speed: 2.0ms preprocess, 35.2ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 75 objects, 35.2ms
# Speed: 2.1ms preprocess, 35.2ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 75 objects, 35.2ms
# Speed: 2.1ms preprocess, 35.2ms inference, 2.3ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 75 objects, 35.3ms
# Speed: 2.3ms preprocess, 35.3ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 14
#
# 0: 1280x704 4 chairs, 2 sofas, 1 stool, 22.9ms
# Speed: 1.7ms preprocess, 22.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 62 objects, 36.7ms
# Speed: 1.8ms preprocess, 36.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 62 objects, 36.7ms
# Speed: 2.1ms preprocess, 36.7ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 62 objects, 35.4ms
# Speed: 2.1ms preprocess, 35.4ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 62 objects, 35.3ms
# Speed: 2.2ms preprocess, 35.3ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 62 objects, 35.3ms
# Speed: 2.2ms preprocess, 35.3ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 62 objects, 35.2ms
# Speed: 2.2ms preprocess, 35.2ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 62 objects, 35.2ms
# Speed: 2.1ms preprocess, 35.2ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 15
#
# 0: 1280x704 2 sofas, 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 41 objects, 36.7ms
# Speed: 1.8ms preprocess, 36.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 41 objects, 36.7ms
# Speed: 2.3ms preprocess, 36.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 16
#
# 0: 1280x704 3 chairs, 22.9ms
# Speed: 1.7ms preprocess, 22.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 30 objects, 36.7ms
# Speed: 1.9ms preprocess, 36.7ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 30 objects, 35.9ms
# Speed: 2.0ms preprocess, 35.9ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 30 objects, 35.9ms
# Speed: 2.1ms preprocess, 35.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 17
#
# 0: 1280x704 2 chairs, 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 36 objects, 36.7ms
# Speed: 1.8ms preprocess, 36.7ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 36 objects, 36.8ms
# Speed: 2.0ms preprocess, 36.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 18
#
# 0: 1280x704 2 chairs, 22.9ms
# Speed: 1.7ms preprocess, 22.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 44 objects, 36.7ms
# Speed: 1.8ms preprocess, 36.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 44 objects, 36.8ms
# Speed: 2.1ms preprocess, 36.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 19
#
# 0: 1280x704 2 chairs, 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 59 objects, 36.7ms
# Speed: 1.8ms preprocess, 36.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 59 objects, 36.8ms
# Speed: 2.2ms preprocess, 36.8ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 20
#
# 0: 1280x704 1 chair, 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.6ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 68 objects, 36.8ms
# Speed: 1.8ms preprocess, 36.8ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 21
#
# 0: 1280x704 (no detections), 22.9ms
# Speed: 1.9ms preprocess, 22.9ms inference, 0.2ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 22
#
# 0: 1280x704 (no detections), 22.9ms
# Speed: 1.7ms preprocess, 22.9ms inference, 0.2ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 23
#
# 0: 1280x704 (no detections), 22.9ms
# Speed: 1.7ms preprocess, 22.9ms inference, 0.3ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 24
#
# 0: 1280x704 (no detections), 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.3ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 25
#
# 0: 1280x704 (no detections), 22.8ms
# Speed: 1.8ms preprocess, 22.8ms inference, 0.2ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 26
#
# 0: 1280x704 (no detections), 22.9ms
# Speed: 1.9ms preprocess, 22.9ms inference, 0.3ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 27
#
# 0: 1280x704 (no detections), 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.3ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 28
#
# 0: 1280x704 (no detections), 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.3ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 29
#
# 0: 1280x704 (no detections), 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.2ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 30
#
# 0: 1280x704 (no detections), 22.9ms
# Speed: 1.9ms preprocess, 22.9ms inference, 0.3ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 31
#
# 0: 1280x704 (no detections), 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.2ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 32
#
# 0: 1280x704 1 chair, 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 75 objects, 36.7ms
# Speed: 1.9ms preprocess, 36.7ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 33
#
# 0: 1280x704 (no detections), 22.9ms
# Speed: 3.0ms preprocess, 22.9ms inference, 0.3ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 34
#
# 0: 1280x704 1 person, 1 sofa, 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 60 objects, 36.7ms
# Speed: 1.8ms preprocess, 36.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 60 objects, 36.7ms
# Speed: 2.2ms preprocess, 36.7ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 35
#
# 0: 1280x704 1 chair, 1 person, 3 sofas, 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 53 objects, 36.7ms
# Speed: 1.7ms preprocess, 36.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 53 objects, 36.2ms
# Speed: 2.1ms preprocess, 36.2ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 53 objects, 35.4ms
# Speed: 2.1ms preprocess, 35.4ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 53 objects, 35.3ms
# Speed: 2.2ms preprocess, 35.3ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 53 objects, 35.2ms
# Speed: 2.7ms preprocess, 35.2ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 36
#
# 0: 1280x704 1 chair, 2 sofas, 22.9ms
# Speed: 1.7ms preprocess, 22.9ms inference, 0.6ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 46 objects, 36.6ms
# Speed: 1.9ms preprocess, 36.6ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 46 objects, 35.4ms
# Speed: 2.1ms preprocess, 35.4ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 46 objects, 35.3ms
# Speed: 1.9ms preprocess, 35.3ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 37
#
# 0: 1280x704 1 chair, 2 sofas, 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 51 objects, 36.7ms
# Speed: 1.7ms preprocess, 36.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 51 objects, 36.7ms
# Speed: 2.0ms preprocess, 36.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 51 objects, 36.8ms
# Speed: 1.9ms preprocess, 36.8ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 38
#
# 0: 1280x704 (no detections), 23.0ms
# Speed: 1.8ms preprocess, 23.0ms inference, 0.2ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 39
#
# 0: 1280x704 2 chairs, 1 sofa, 1 coffee table, 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 50 objects, 36.8ms
# Speed: 1.9ms preprocess, 36.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 50 objects, 36.4ms
# Speed: 2.1ms preprocess, 36.4ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 50 objects, 35.3ms
# Speed: 2.0ms preprocess, 35.3ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 50 objects, 35.3ms
# Speed: 2.0ms preprocess, 35.3ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 40
#
# 0: 1280x704 (no detections), 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.3ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 41
#
# 0: 1280x704 1 chair, 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.6ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 97 objects, 36.6ms
# Speed: 1.9ms preprocess, 36.6ms inference, 2.5ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 42
#
# 0: 1280x704 (no detections), 22.9ms
# Speed: 1.7ms preprocess, 22.9ms inference, 0.3ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 43
#
# 0: 1280x704 (no detections), 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.2ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 44
#
# 0: 1280x704 1 chair, 22.9ms
# Speed: 2.0ms preprocess, 22.9ms inference, 0.6ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 76 objects, 36.7ms
# Speed: 1.8ms preprocess, 36.7ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 45
#
# 0: 1280x704 1 sink, 22.9ms
# Speed: 1.7ms preprocess, 22.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 91 objects, 36.7ms
# Speed: 1.8ms preprocess, 36.7ms inference, 2.4ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 46
#
# 0: 1280x704 1 sink, 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 77 objects, 36.9ms
# Speed: 1.8ms preprocess, 36.9ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 47
#
# 0: 1280x704 1 sink, 22.9ms
# Speed: 1.9ms preprocess, 22.9ms inference, 0.6ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 74 objects, 36.7ms
# Speed: 1.8ms preprocess, 36.7ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 48
#
# 0: 1280x704 1 chair, 22.8ms
# Speed: 1.8ms preprocess, 22.8ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 43 objects, 36.8ms
# Speed: 1.8ms preprocess, 36.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 49
#
# 0: 1280x704 (no detections), 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.3ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 50
#
# 0: 1280x704 (no detections), 22.9ms
# Speed: 1.9ms preprocess, 22.9ms inference, 0.4ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 51
#
# 0: 1280x704 1 sink, 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 48 objects, 36.6ms
# Speed: 1.8ms preprocess, 36.6ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 52
#
# 0: 1280x704 1 sink, 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 64 objects, 36.9ms
# Speed: 1.8ms preprocess, 36.9ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 53
#
# 0: 1280x704 1 chair, 22.8ms
# Speed: 1.8ms preprocess, 22.8ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 52 objects, 36.7ms
# Speed: 1.8ms preprocess, 36.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 54
#
# 0: 1280x704 1 chair, 22.9ms
# Speed: 3.3ms preprocess, 22.9ms inference, 0.6ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 46 objects, 36.7ms
# Speed: 1.8ms preprocess, 36.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 55
#
# 0: 1280x704 1 sink, 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 48 objects, 36.7ms
# Speed: 1.7ms preprocess, 36.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 56
#
# 0: 1280x704 1 sink, 22.9ms
# Speed: 1.9ms preprocess, 22.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 66 objects, 36.7ms
# Speed: 1.7ms preprocess, 36.7ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 57
#
# 0: 1280x704 1 sink, 22.8ms
# Speed: 2.0ms preprocess, 22.8ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 62 objects, 36.7ms
# Speed: 1.8ms preprocess, 36.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 58
#
# 0: 1280x704 (no detections), 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.3ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 59
#
# 0: 1280x704 1 cup, 1 sink, 22.9ms
# Speed: 1.9ms preprocess, 22.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 71 objects, 36.7ms
# Speed: 1.8ms preprocess, 36.7ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 71 objects, 35.2ms
# Speed: 2.1ms preprocess, 35.2ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 60
#
# 0: 1280x704 1 cup, 1 sink, 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 71 objects, 36.6ms
# Speed: 1.9ms preprocess, 36.6ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 71 objects, 35.2ms
# Speed: 2.1ms preprocess, 35.2ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 61
#
# 0: 1280x704 1 cup, 1 sink, 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 79 objects, 36.7ms
# Speed: 1.8ms preprocess, 36.7ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 79 objects, 36.7ms
# Speed: 1.9ms preprocess, 36.7ms inference, 2.3ms postprocess per image at shape (1, 3, 1280, 704)
# File Name: rosbag2_2024_05_16-05_13_58.pkl
# Key Frame: 0
#
# 0: 1280x704 3 chairs, 2 sofas, 22.9ms
# Speed: 1.9ms preprocess, 22.9ms inference, 0.6ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 47 objects, 36.7ms
# Speed: 1.8ms preprocess, 36.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 47 objects, 36.8ms
# Speed: 2.0ms preprocess, 36.8ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 47 objects, 35.9ms
# Speed: 1.9ms preprocess, 35.9ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 47 objects, 35.2ms
# Speed: 1.9ms preprocess, 35.2ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 47 objects, 35.2ms
# Speed: 1.9ms preprocess, 35.2ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 1
#
# 0: 1280x704 3 chairs, 2 sofas, 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 44 objects, 36.7ms
# Speed: 1.8ms preprocess, 36.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 44 objects, 35.7ms
# Speed: 1.9ms preprocess, 35.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 44 objects, 35.3ms
# Speed: 1.9ms preprocess, 35.3ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 44 objects, 35.2ms
# Speed: 2.0ms preprocess, 35.2ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 44 objects, 35.2ms
# Speed: 2.1ms preprocess, 35.2ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 2
#
# 0: 1280x704 4 chairs, 1 stool, 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 48 objects, 36.7ms
# Speed: 1.9ms preprocess, 36.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 48 objects, 35.3ms
# Speed: 1.9ms preprocess, 35.3ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 48 objects, 35.3ms
# Speed: 1.9ms preprocess, 35.3ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 48 objects, 35.2ms
# Speed: 1.9ms preprocess, 35.2ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 48 objects, 35.2ms
# Speed: 2.1ms preprocess, 35.2ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 3
#
# 0: 1280x704 6 chairs, 1 sofa, 1 stool, 1 coffee table, 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 54 objects, 36.7ms
# Speed: 2.0ms preprocess, 36.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 54 objects, 36.8ms
# Speed: 1.9ms preprocess, 36.8ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 54 objects, 36.7ms
# Speed: 1.9ms preprocess, 36.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 54 objects, 36.8ms
# Speed: 1.9ms preprocess, 36.8ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 54 objects, 35.3ms
# Speed: 2.0ms preprocess, 35.3ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 54 objects, 35.3ms
# Speed: 1.9ms preprocess, 35.3ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 54 objects, 35.3ms
# Speed: 1.9ms preprocess, 35.3ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 54 objects, 35.3ms
# Speed: 1.9ms preprocess, 35.3ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 54 objects, 35.2ms
# Speed: 1.9ms preprocess, 35.2ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 4
#
# 0: 1280x704 4 chairs, 2 sofas, 2 stools, 1 coffee table, 22.8ms
# Speed: 1.8ms preprocess, 22.8ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 72 objects, 36.8ms
# Speed: 1.8ms preprocess, 36.8ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 72 objects, 36.7ms
# Speed: 1.9ms preprocess, 36.7ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 72 objects, 36.8ms
# Speed: 2.0ms preprocess, 36.8ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 72 objects, 35.2ms
# Speed: 1.9ms preprocess, 35.2ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 72 objects, 35.2ms
# Speed: 2.0ms preprocess, 35.2ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 72 objects, 35.2ms
# Speed: 1.9ms preprocess, 35.2ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 72 objects, 35.2ms
# Speed: 1.9ms preprocess, 35.2ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 72 objects, 35.4ms
# Speed: 2.0ms preprocess, 35.4ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 72 objects, 35.2ms
# Speed: 1.9ms preprocess, 35.2ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 5
#
# 0: 1280x704 1 sofa, 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 67 objects, 36.7ms
# Speed: 1.8ms preprocess, 36.7ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 6
#
# 0: 1280x704 1 chair, 22.9ms
# Speed: 3.3ms preprocess, 22.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 49 objects, 36.8ms
# Speed: 1.8ms preprocess, 36.8ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 7
#
# 0: 1280x704 4 chairs, 22.9ms
# Speed: 1.9ms preprocess, 22.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 32 objects, 36.7ms
# Speed: 1.8ms preprocess, 36.7ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 32 objects, 36.8ms
# Speed: 2.1ms preprocess, 36.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 32 objects, 36.8ms
# Speed: 1.9ms preprocess, 36.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 32 objects, 35.2ms
# Speed: 2.0ms preprocess, 35.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 8
#
# 0: 1280x704 4 chairs, 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 28 objects, 36.7ms
# Speed: 1.9ms preprocess, 36.7ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 28 objects, 36.8ms
# Speed: 1.9ms preprocess, 36.8ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 28 objects, 36.8ms
# ...
# Speed: 2.3ms preprocess, 36.8ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 55 objects, 35.2ms
# Speed: 2.3ms preprocess, 35.2ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 55 objects, 35.2ms
# Speed: 2.3ms preprocess, 35.2ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 55 objects, 35.2ms
# Speed: 2.3ms preprocess, 35.2ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 55 objects, 35.3ms
# Speed: 2.2ms preprocess, 35.3ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 55 objects, 35.3ms
# Speed: 1.9ms preprocess, 35.3ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 55 objects, 35.2ms
# Speed: 1.9ms preprocess, 35.2ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 10
#
# 0: 1280x704 1 cup, 3 chairs, 2 sofas, 1 coffee table, 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 59 objects, 36.8ms
# Speed: 1.9ms preprocess, 36.8ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 59 objects, 35.7ms
# Speed: 2.1ms preprocess, 35.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 59 objects, 35.2ms
# Speed: 2.2ms preprocess, 35.2ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 59 objects, 35.2ms
# Speed: 2.4ms preprocess, 35.2ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 59 objects, 35.2ms
# Speed: 2.1ms preprocess, 35.2ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 59 objects, 35.2ms
# Speed: 2.0ms preprocess, 35.2ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 59 objects, 35.2ms
# Speed: 2.4ms preprocess, 35.2ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 11
#
# 0: 1280x704 1 cup, 4 chairs, 2 sofas, 1 coffee table, 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 64 objects, 36.8ms
# Speed: 1.8ms preprocess, 36.8ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 64 objects, 36.8ms
# Speed: 2.0ms preprocess, 36.8ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 64 objects, 36.7ms
# Speed: 2.0ms preprocess, 36.7ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 64 objects, 36.8ms
# Speed: 2.1ms preprocess, 36.8ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 64 objects, 35.5ms
# Speed: 2.1ms preprocess, 35.5ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 64 objects, 35.4ms
# Speed: 2.3ms preprocess, 35.4ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 64 objects, 35.7ms
# Speed: 2.1ms preprocess, 35.7ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 64 objects, 35.3ms
# Speed: 2.0ms preprocess, 35.3ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 12
#
# 0: 1280x704 1 cup, 2 chairs, 2 sofas, 1 stool, 21.9ms
# Speed: 1.8ms preprocess, 21.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 68 objects, 35.4ms
# Speed: 1.8ms preprocess, 35.4ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 68 objects, 35.2ms
# Speed: 2.0ms preprocess, 35.2ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 68 objects, 35.3ms
# Speed: 2.0ms preprocess, 35.3ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 68 objects, 35.3ms
# Speed: 2.0ms preprocess, 35.3ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 68 objects, 35.3ms
# Speed: 2.0ms preprocess, 35.3ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 68 objects, 35.2ms
# Speed: 1.9ms preprocess, 35.2ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 13
#
# 0: 1280x704 3 chairs, 2 sofas, 1 stool, 1 coffee table, 25.2ms
# Speed: 1.9ms preprocess, 25.2ms inference, 0.7ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 59 objects, 38.8ms
# Speed: 2.1ms preprocess, 38.8ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 59 objects, 39.1ms
# Speed: 2.2ms preprocess, 39.1ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 59 objects, 69.3ms
# Speed: 3.1ms preprocess, 69.3ms inference, 21.7ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 59 objects, 66.7ms
# Speed: 3.8ms preprocess, 66.7ms inference, 3.6ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 59 objects, 75.0ms
# Speed: 2.5ms preprocess, 75.0ms inference, 3.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 59 objects, 40.0ms
# Speed: 2.3ms preprocess, 40.0ms inference, 21.7ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 59 objects, 44.7ms
# Speed: 2.1ms preprocess, 44.7ms inference, 21.7ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 14
#
# 0: 1280x704 2 chairs, 25.6ms
# Speed: 2.5ms preprocess, 25.6ms inference, 0.6ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 35 objects, 38.9ms
# Speed: 2.0ms preprocess, 38.9ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 35 objects, 39.6ms
# Speed: 2.1ms preprocess, 39.6ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 15
#
# 0: 1280x704 4 chairs, 22.9ms
# Speed: 2.1ms preprocess, 22.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 49 objects, 36.7ms
# Speed: 2.0ms preprocess, 36.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 49 objects, 36.7ms
# Speed: 1.9ms preprocess, 36.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 49 objects, 35.9ms
# Speed: 2.1ms preprocess, 35.9ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 49 objects, 35.2ms
# Speed: 2.0ms preprocess, 35.2ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 16
#
# 0: 1280x704 2 chairs, 24.4ms
# Speed: 2.1ms preprocess, 24.4ms inference, 0.8ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 36 objects, 35.5ms
# Speed: 1.8ms preprocess, 35.5ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 36 objects, 35.3ms
# Speed: 2.1ms preprocess, 35.3ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 17
#
# 0: 1280x704 1 chair, 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 54 objects, 36.7ms
# Speed: 1.8ms preprocess, 36.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 18
#
# 0: 1280x704 2 chairs, 23.1ms
# Speed: 2.0ms preprocess, 23.1ms inference, 0.7ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 61 objects, 36.7ms
# Speed: 2.1ms preprocess, 36.7ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 61 objects, 36.8ms
# Speed: 2.5ms preprocess, 36.8ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 19
#
# 0: 1280x704 (no detections), 21.9ms
# Speed: 1.8ms preprocess, 21.9ms inference, 0.2ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 20
#
# 0: 1280x704 (no detections), 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.3ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 21
#
# 0: 1280x704 (no detections), 23.0ms
# Speed: 1.9ms preprocess, 23.0ms inference, 0.3ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 22
#
# 0: 1280x704 (no detections), 21.9ms
# Speed: 1.9ms preprocess, 21.9ms inference, 0.2ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 23
#
# 0: 1280x704 (no detections), 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.3ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 24
#
# 0: 1280x704 (no detections), 24.5ms
# Speed: 2.1ms preprocess, 24.5ms inference, 0.3ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 25
#
# 0: 1280x704 (no detections), 23.1ms
# Speed: 1.8ms preprocess, 23.1ms inference, 0.3ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 26
#
# 0: 1280x704 (no detections), 22.9ms
# Speed: 2.6ms preprocess, 22.9ms inference, 0.2ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 27
#
# 0: 1280x704 (no detections), 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.4ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 28
#
# 0: 1280x704 (no detections), 23.2ms
# Speed: 2.3ms preprocess, 23.2ms inference, 0.9ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 29
#
# 0: 1280x704 1 sink, 21.9ms
# Speed: 1.8ms preprocess, 21.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 128 objects, 37.0ms
# Speed: 1.8ms preprocess, 37.0ms inference, 3.5ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 30
#
# 0: 1280x704 (no detections), 22.9ms
# Speed: 1.9ms preprocess, 22.9ms inference, 0.2ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 31
#
# 0: 1280x704 (no detections), 23.0ms
# Speed: 2.0ms preprocess, 23.0ms inference, 0.3ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 32
#
# 0: 1280x704 (no detections), 21.9ms
# Speed: 1.8ms preprocess, 21.9ms inference, 0.3ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 33
#
# 0: 1280x704 (no detections), 22.9ms
# Speed: 1.9ms preprocess, 22.9ms inference, 0.3ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 34
#
# 0: 1280x704 (no detections), 23.3ms
# Speed: 4.1ms preprocess, 23.3ms inference, 0.4ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 35
#
# 0: 1280x704 (no detections), 21.9ms
# Speed: 1.9ms preprocess, 21.9ms inference, 0.3ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 36
#
# 0: 1280x704 (no detections), 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.3ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 37
#
# 0: 1280x704 (no detections), 23.0ms
# Speed: 2.6ms preprocess, 23.0ms inference, 0.4ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 38
#
# 0: 1280x704 (no detections), 21.9ms
# Speed: 1.8ms preprocess, 21.9ms inference, 0.2ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 39
#
# 0: 1280x704 (no detections), 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.2ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 40
#
# 0: 1280x704 (no detections), 22.9ms
# Speed: 1.9ms preprocess, 22.9ms inference, 0.3ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 41
#
# 0: 1280x704 (no detections), 21.9ms
# Speed: 1.8ms preprocess, 21.9ms inference, 0.3ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 42
#
# 0: 1280x704 1 chair, 1 sink, 22.9ms
# Speed: 2.0ms preprocess, 22.9ms inference, 0.6ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 71 objects, 36.8ms
# Speed: 1.9ms preprocess, 36.8ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 71 objects, 35.7ms
# Speed: 2.4ms preprocess, 35.7ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 43
#
# 0: 1280x704 1 chair, 21.9ms
# Speed: 1.8ms preprocess, 21.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 51 objects, 35.3ms
# Speed: 1.8ms preprocess, 35.3ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 44
#
# 0: 1280x704 4 chairs, 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 54 objects, 36.7ms
# Speed: 1.8ms preprocess, 36.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 54 objects, 36.0ms
# Speed: 2.3ms preprocess, 36.0ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 54 objects, 35.2ms
# Speed: 1.9ms preprocess, 35.2ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 54 objects, 35.2ms
# Speed: 1.9ms preprocess, 35.2ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 45
#
# 0: 1280x704 (no detections), 22.0ms
# Speed: 1.9ms preprocess, 22.0ms inference, 0.3ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 46
#
# 0: 1280x704 (no detections), 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.2ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 47
#
# 0: 1280x704 1 sink, 24.6ms
# Speed: 1.9ms preprocess, 24.6ms inference, 0.7ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 59 objects, 35.9ms
# Speed: 2.0ms preprocess, 35.9ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 48
#
# 0: 1280x704 1 sink, 22.9ms
# Speed: 1.7ms preprocess, 22.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 57 objects, 36.8ms
# Speed: 1.9ms preprocess, 36.8ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 49
#
# 0: 1280x704 (no detections), 23.0ms
# Speed: 2.1ms preprocess, 23.0ms inference, 0.4ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 50
#
# 0: 1280x704 1 chair, 32.7ms
# Speed: 2.3ms preprocess, 32.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 63 objects, 35.3ms
# Speed: 1.8ms preprocess, 35.3ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 51
#
# 0: 1280x704 (no detections), 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.3ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 52
#
# 0: 1280x704 (no detections), 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.3ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 53
#
# 0: 1280x704 1 sink, 22.0ms
# Speed: 1.9ms preprocess, 22.0ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 56 objects, 35.4ms
# Speed: 1.8ms preprocess, 35.4ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 54
#
# 0: 1280x704 1 sink, 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.6ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 68 objects, 36.7ms
# Speed: 1.8ms preprocess, 36.7ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 55
#
# 0: 1280x704 1 cup, 1 sink, 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.7ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 56 objects, 36.7ms
# Speed: 1.8ms preprocess, 36.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 56 objects, 36.8ms
# Speed: 2.1ms preprocess, 36.8ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 56
#
# 0: 1280x704 1 cup, 22.0ms
# Speed: 1.7ms preprocess, 22.0ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 60 objects, 35.4ms
# Speed: 1.8ms preprocess, 35.4ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 57
#
# 0: 1280x704 (no detections), 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.3ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 58
#
# 0: 1280x704 1 cup, 1 sink, 23.0ms
# Speed: 2.0ms preprocess, 23.0ms inference, 0.7ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 73 objects, 39.6ms
# Speed: 1.9ms preprocess, 39.6ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 73 objects, 65.3ms
# Speed: 3.0ms preprocess, 65.3ms inference, 18.8ms postprocess per image at shape (1, 3, 1280, 704)
# Key Frame: 59
#
# 0: 1280x704 1 cup, 1 sink, 22.8ms
# Speed: 1.8ms preprocess, 22.8ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 73 objects, 36.7ms
# Speed: 2.8ms preprocess, 36.7ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x704 73 objects, 36.7ms
# Speed: 2.1ms preprocess, 36.7ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 704)

# %% [markdown]
# #### Internal

# %%
internal_summaries = []
for file_name in files:
    if '.json' not in file_name:
        print('File Name:', file_name)
        file_path = path + file_name
        data = load_pickle(file_path)
        data['camera_info'] = camera_info
        env_summary = []
        for i in range(len(data['rgb'])):
            print('Key Frame:', str(i))
            keyframe = {'rgb': data['rgb'][i], 
                        'depth': data['depth'][i], 
                        'odom': data['odom'][i], 
                        'joint_state': data['joint_state'][i], 
                        'camera_info': data['camera_info']}
            internal_summary = narr_engine.summarize_internal(keyframe)
            internal_summaries.append(internal_summary)
            with open(file_path.replace('.pkl', '_internal_sum.json'), 'w') as f:
                json.dump({'internal_sum': internal_summaries}, f)
# Out:
# File Name: rosbag2_2024_05_15-01_10_46.pkl
# Key Frame: 0
# Key Frame: 1
# Key Frame: 2
# Key Frame: 3
# Key Frame: 4
# Key Frame: 5
# Key Frame: 6
# Key Frame: 7
# Key Frame: 8
# Key Frame: 9
# Key Frame: 10
# Key Frame: 11
# Key Frame: 12
# Key Frame: 13
# Key Frame: 14
# Key Frame: 15
# Key Frame: 16
# Key Frame: 17
# Key Frame: 18
# Key Frame: 19
# Key Frame: 20
# Key Frame: 21
# Key Frame: 22
# Key Frame: 23
# Key Frame: 24
# Key Frame: 25
# Key Frame: 26
# Key Frame: 27
# Key Frame: 28
# Key Frame: 29
# Key Frame: 30
# Key Frame: 31
# Key Frame: 32
# Key Frame: 33
# Key Frame: 34
# Key Frame: 35
# Key Frame: 36
# Key Frame: 37
# Key Frame: 38
# Key Frame: 39
# Key Frame: 40
# Key Frame: 41
# Key Frame: 42
# Key Frame: 43
# Key Frame: 44
# Key Frame: 45
# File Name: rosbag2_2024_05_15-01_19_23.pkl
# Key Frame: 0
# Key Frame: 1
# Key Frame: 2
# Key Frame: 3
# Key Frame: 4
# Key Frame: 5
# Key Frame: 6
# Key Frame: 7
# Key Frame: 8
# Key Frame: 9
# Key Frame: 10
# Key Frame: 11
# Key Frame: 12
# Key Frame: 13
# Key Frame: 14
# Key Frame: 15
# Key Frame: 16
# Key Frame: 17
# Key Frame: 18
# Key Frame: 19
# Key Frame: 20
# Key Frame: 21
# Key Frame: 22
# Key Frame: 23
# Key Frame: 24
# Key Frame: 25
# Key Frame: 26
# Key Frame: 27
# Key Frame: 28
# Key Frame: 29
# Key Frame: 30
# Key Frame: 31
# Key Frame: 32
# Key Frame: 33
# Key Frame: 34
# Key Frame: 35
# Key Frame: 36
# Key Frame: 37
# Key Frame: 38
# Key Frame: 39
# Key Frame: 40
# Key Frame: 41
# Key Frame: 42
# Key Frame: 43
# File Name: rosbag2_2024_05_15-01_30_06.pkl
# Key Frame: 0
# Key Frame: 1
# Key Frame: 2
# Key Frame: 3
# Key Frame: 4
# Key Frame: 5
# Key Frame: 6
# Key Frame: 7
# Key Frame: 8
# Key Frame: 9
# Key Frame: 10
# Key Frame: 11
# Key Frame: 12
# Key Frame: 13
# Key Frame: 14
# Key Frame: 15
# Key Frame: 16
# Key Frame: 17
# Key Frame: 18
# Key Frame: 19
# Key Frame: 20
# Key Frame: 21
# Key Frame: 22
# Key Frame: 23
# Key Frame: 24
# Key Frame: 25
# Key Frame: 26
# Key Frame: 27
# Key Frame: 28
# Key Frame: 29
# Key Frame: 30
# Key Frame: 31
# Key Frame: 32
# Key Frame: 33
# Key Frame: 34
# Key Frame: 35
# File Name: rosbag2_2024_05_15-01_39_05.pkl
# Key Frame: 0
# Key Frame: 1
# Key Frame: 2
# Key Frame: 3
# Key Frame: 4
# Key Frame: 5
# Key Frame: 6
# Key Frame: 7
# Key Frame: 8
# Key Frame: 9
# Key Frame: 10
# Key Frame: 11
# Key Frame: 12
# Key Frame: 13
# Key Frame: 14
# Key Frame: 15
# Key Frame: 16
# Key Frame: 17
# Key Frame: 18
# Key Frame: 19
# Key Frame: 20
# Key Frame: 21
# Key Frame: 22
# Key Frame: 23
# Key Frame: 24
# Key Frame: 25
# Key Frame: 26
# Key Frame: 27
# Key Frame: 28
# Key Frame: 29
# Key Frame: 30
# Key Frame: 31
# Key Frame: 32
# Key Frame: 33
# File Name: rosbag2_2024_05_15-01_44_42.pkl
# Key Frame: 0
# Key Frame: 1
# Key Frame: 2
# Key Frame: 3
# Key Frame: 4
# Key Frame: 5
# Key Frame: 6
# Key Frame: 7
# Key Frame: 8
# Key Frame: 9
# Key Frame: 10
# Key Frame: 11
# Key Frame: 12
# Key Frame: 13
# Key Frame: 14
# Key Frame: 15
# Key Frame: 16
# Key Frame: 17
# Key Frame: 18
# Key Frame: 19
# Key Frame: 20
# Key Frame: 21
# Key Frame: 22
# Key Frame: 23
# Key Frame: 24
# Key Frame: 25
# Key Frame: 26
# Key Frame: 27
# Key Frame: 28
# Key Frame: 29
# Key Frame: 30
# File Name: rosbag2_2024_05_15-01_53_03.pkl
# Key Frame: 0
# Key Frame: 1
# Key Frame: 2
# Key Frame: 3
# Key Frame: 4
# Key Frame: 5
# Key Frame: 6
# Key Frame: 7
# Key Frame: 8
# Key Frame: 9
# Key Frame: 10
# Key Frame: 11
# Key Frame: 12
# Key Frame: 13
# Key Frame: 14
# Key Frame: 15
# Key Frame: 16
# Key Frame: 17
# Key Frame: 18
# Key Frame: 19
# Key Frame: 20
# Key Frame: 21
# Key Frame: 22
# Key Frame: 23
# Key Frame: 24
# Key Frame: 25
# Key Frame: 26
# Key Frame: 27
# Key Frame: 28
# Key Frame: 29
# Key Frame: 30
# Key Frame: 31
# Key Frame: 32
# Key Frame: 33
# Key Frame: 34
# Key Frame: 35
# Key Frame: 36
# Key Frame: 37
# Key Frame: 38
# Key Frame: 39
# Key Frame: 40
# File Name: rosbag2_2024_05_15-02_00_10.pkl
# Key Frame: 0
# Key Frame: 1
# Key Frame: 2
# Key Frame: 3
# Key Frame: 4
# Key Frame: 5
# Key Frame: 6
# Key Frame: 7
# Key Frame: 8
# Key Frame: 9
# Key Frame: 10
# Key Frame: 11
# Key Frame: 12
# Key Frame: 13
# Key Frame: 14
# Key Frame: 15
# Key Frame: 16
# Key Frame: 17
# Key Frame: 18
# Key Frame: 19
# Key Frame: 20
# Key Frame: 21
# Key Frame: 22
# Key Frame: 23
# Key Frame: 24
# Key Frame: 25
# Key Frame: 26
# Key Frame: 27
# Key Frame: 28
# Key Frame: 29
# Key Frame: 30
# Key Frame: 31
# Key Frame: 32
# Key Frame: 33
# File Name: rosbag2_2024_05_15-23_34_06.pkl
# Key Frame: 0
# Key Frame: 1
# Key Frame: 2
# Key Frame: 3
# Key Frame: 4
# Key Frame: 5
# Key Frame: 6
# Key Frame: 7
# Key Frame: 8
# Key Frame: 9
# Key Frame: 10
# Key Frame: 11
# Key Frame: 12
# Key Frame: 13
# Key Frame: 14
# Key Frame: 15
# Key Frame: 16
# Key Frame: 17
# Key Frame: 18
# Key Frame: 19
# Key Frame: 20
# Key Frame: 21
# Key Frame: 22
# Key Frame: 23
# Key Frame: 24
# Key Frame: 25
# Key Frame: 26
# Key Frame: 27
# Key Frame: 28
# Key Frame: 29
# Key Frame: 30
# Key Frame: 31
# Key Frame: 32
# Key Frame: 33
# File Name: rosbag2_2024_05_15-23_45_03.pkl
# Key Frame: 0
# Key Frame: 1
# Key Frame: 2
# Key Frame: 3
# Key Frame: 4
# Key Frame: 5
# Key Frame: 6
# Key Frame: 7
# Key Frame: 8
# Key Frame: 9
# Key Frame: 10
# Key Frame: 11
# Key Frame: 12
# Key Frame: 13
# Key Frame: 14
# Key Frame: 15
# Key Frame: 16
# Key Frame: 17
# Key Frame: 18
# Key Frame: 19
# Key Frame: 20
# Key Frame: 21
# Key Frame: 22
# Key Frame: 23
# Key Frame: 24
# Key Frame: 25
# Key Frame: 26
# Key Frame: 27
# Key Frame: 28
# Key Frame: 29
# Key Frame: 30
# Key Frame: 31
# Key Frame: 32
# Key Frame: 33
# Key Frame: 34
# Key Frame: 35
# Key Frame: 36
# Key Frame: 37
# Key Frame: 38
# Key Frame: 39
# Key Frame: 40
# Key Frame: 41
# Key Frame: 42
# Key Frame: 43
# Key Frame: 44
# Key Frame: 45
# Key Frame: 46
# Key Frame: 47
# Key Frame: 48
# Key Frame: 49
# Key Frame: 50
# Key Frame: 51
# Key Frame: 52
# Key Frame: 53
# Key Frame: 54
# Key Frame: 55
# Key Frame: 56
# Key Frame: 57
# Key Frame: 58
# Key Frame: 59
# Key Frame: 60
# Key Frame: 61
# File Name: rosbag2_2024_05_15-23_57_32.pkl
# Key Frame: 0
# Key Frame: 1
# Key Frame: 2
# Key Frame: 3
# Key Frame: 4
# Key Frame: 5
# Key Frame: 6
# Key Frame: 7
# Key Frame: 8
# Key Frame: 9
# Key Frame: 10
# Key Frame: 11
# Key Frame: 12
# Key Frame: 13
# Key Frame: 14
# Key Frame: 15
# Key Frame: 16
# Key Frame: 17
# Key Frame: 18
# Key Frame: 19
# Key Frame: 20
# Key Frame: 21
# Key Frame: 22
# Key Frame: 23
# Key Frame: 24
# Key Frame: 25
# Key Frame: 26
# Key Frame: 27
# Key Frame: 28
# Key Frame: 29
# Key Frame: 30
# Key Frame: 31
# Key Frame: 32
# Key Frame: 33
# Key Frame: 34
# File Name: rosbag2_2024_05_16-00_06_13.pkl
# Key Frame: 0
# Key Frame: 1
# Key Frame: 2
# Key Frame: 3
# Key Frame: 4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 16
#      10 print('Key Frame:', str(i))
#      11 keyframe = {'rgb': data['rgb'][i],
#      12             'depth': data['depth'][i],
#      13             'odom': data['odom'][i],
#      14             'joint_state': data['joint_state'][i],
#      15             'camera_info': data['camera_info']}
# ---> 16 internal_summary = narr_engine.summarize_internal(keyframe)
#      17 internal_summaries.append(internal_summary)
#      18 with open(file_path.replace('.pkl', '_internal_sum.json'), 'w') as f:
#
# File ~/temp/nar/reasoning/llm_engine.py:74, in NarrationEngine.summarize_internal(self, keyframe, personal_pronoun)
#      68 internal_template = prompt_env.get_template('internal_summary.txt')
#      69 internal_prompt = internal_template.render(
#      70     joints = keyframe['joint_state'],
#      71     odom = keyframe['odom'],
#      72 )
# ---> 74 internal_summary = self._get_llm_response(prompt=internal_sys_prompt, query=internal_prompt)
#      75 return internal_summary
#
# File ~/temp/nar/reasoning/llm_engine.py:30, in NarrationEngine._get_llm_response(self, prompt, query)
#      29 def _get_llm_response(self, prompt=None, query=None):
# ---> 30   response = self._narrator.chat.completions.create(
#      31      messages=[
#      32         {'role': 'system', 'content': prompt},
#      33         {'role': 'user', 'content': query}
#      34         ],
#      35         model=self.model,
#      36   )
#      37   message = response.choices[0].message.content
#      38   return message
#
# File ~/.local/lib/python3.8/site-packages/openai/_utils/_utils.py:277, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     275             msg = f"Missing required argument: {quote(missing[0])}"
#     276     raise TypeError(msg)
# --> 277 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/openai/resources/chat/completions.py:590, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, presence_penalty, response_format, seed, stop, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     558 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     559 def create(
#     560     self,
#    (...)
#     588     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     589 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
# --> 590     return self._post(
#     591         "/chat/completions",
#     592         body=maybe_transform(
#     593             {
#     594                 "messages": messages,
#     595                 "model": model,
#     596                 "frequency_penalty": frequency_penalty,
#     597                 "function_call": function_call,
#     598                 "functions": functions,
#     599                 "logit_bias": logit_bias,
#     600                 "logprobs": logprobs,
#     601                 "max_tokens": max_tokens,
#     602                 "n": n,
#     603                 "presence_penalty": presence_penalty,
#     604                 "response_format": response_format,
#     605                 "seed": seed,
#     606                 "stop": stop,
#     607                 "stream": stream,
#     608                 "stream_options": stream_options,
#     609                 "temperature": temperature,
#     610                 "tool_choice": tool_choice,
#     611                 "tools": tools,
#     612                 "top_logprobs": top_logprobs,
#     613                 "top_p": top_p,
#     614                 "user": user,
#     615             },
#     616             completion_create_params.CompletionCreateParams,
#     617         ),
#     618         options=make_request_options(
#     619             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     620         ),
#     621         cast_to=ChatCompletion,
#     622         stream=stream or False,
#     623         stream_cls=Stream[ChatCompletionChunk],
#     624     )
#
# File ~/.local/lib/python3.8/site-packages/openai/_base_client.py:1240, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1226 def post(
#    1227     self,
#    1228     path: str,
#    (...)
#    1235     stream_cls: type[_StreamT] | None = None,
#    1236 ) -> ResponseT | _StreamT:
#    1237     opts = FinalRequestOptions.construct(
#    1238         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1239     )
# -> 1240     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/.local/lib/python3.8/site-packages/openai/_base_client.py:921, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     912 def request(
#     913     self,
#     914     cast_to: Type[ResponseT],
#    (...)
#     919     stream_cls: type[_StreamT] | None = None,
#     920 ) -> ResponseT | _StreamT:
# --> 921     return self._request(
#     922         cast_to=cast_to,
#     923         options=options,
#     924         stream=stream,
#     925         stream_cls=stream_cls,
#     926         remaining_retries=remaining_retries,
#     927     )
#
# File ~/.local/lib/python3.8/site-packages/openai/_base_client.py:952, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     949 log.debug("Sending HTTP Request: %s %s", request.method, request.url)
#     951 try:
# --> 952     response = self._client.send(
#     953         request,
#     954         stream=stream or self._should_stream_response_body(request=request),
#     955         **kwargs,
#     956     )
#     957 except httpx.TimeoutException as err:
#     958     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File ~/.local/lib/python3.8/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     906 follow_redirects = (
#     907     self.follow_redirects
#     908     if isinstance(follow_redirects, UseClientDefault)
#     909     else follow_redirects
#     910 )
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/.local/lib/python3.8/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/.local/lib/python3.8/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/.local/lib/python3.8/site-packages/httpx/_client.py:1015, in Client._send_single_request(self, request)
#    1010     raise RuntimeError(
#    1011         "Attempted to send an async request with a sync Client instance."
#    1012     )
#    1014 with request_context(request=request):
# -> 1015     response = transport.handle_request(request)
#    1017 assert isinstance(response.stream, SyncByteStream)
#    1019 response.request = request
#
# File ~/.local/lib/python3.8/site-packages/httpx/_transports/default.py:233, in HTTPTransport.handle_request(self, request)
#     220 req = httpcore.Request(
#     221     method=request.method,
#     222     url=httpcore.URL(
#    (...)
#     230     extensions=request.extensions,
#     231 )
#     232 with map_httpcore_exceptions():
# --> 233     resp = self._pool.handle_request(req)
#     235 assert isinstance(resp.stream, typing.Iterable)
#     237 return Response(
#     238     status_code=resp.status,
#     239     headers=resp.headers,
#     240     stream=ResponseStream(resp.stream),
#     241     extensions=resp.extensions,
#     242 )
#
# File ~/.local/lib/python3.8/site-packages/httpcore/_sync/connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     213         closing = self._assign_requests_to_connections()
#     215     self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
#     219 # the point at which the response is closed.
#     220 assert isinstance(response.stream, Iterable)
#
# File ~/.local/lib/python3.8/site-packages/httpcore/_sync/connection_pool.py:196, in ConnectionPool.handle_request(self, request)
#     192 connection = pool_request.wait_for_connection(timeout=timeout)
#     194 try:
#     195     # Send the request on the assigned connection.
# --> 196     response = connection.handle_request(
#     197         pool_request.request
#     198     )
#     199 except ConnectionNotAvailable:
#     200     # In some cases a connection may initially be available to
#     201     # handle a request, but then become unavailable.
#     202     #
#     203     # In this case we clear the connection and try again.
#     204     pool_request.clear_connection()
#
# File ~/.local/lib/python3.8/site-packages/httpcore/_sync/connection.py:101, in HTTPConnection.handle_request(self, request)
#      98     self._connect_failed = True
#      99     raise exc
# --> 101 return self._connection.handle_request(request)
#
# File ~/.local/lib/python3.8/site-packages/httpcore/_sync/http11.py:143, in HTTP11Connection.handle_request(self, request)
#     141     with Trace("response_closed", logger, request) as trace:
#     142         self._response_closed()
# --> 143 raise exc
#
# File ~/.local/lib/python3.8/site-packages/httpcore/_sync/http11.py:113, in HTTP11Connection.handle_request(self, request)
#     102     pass
#     104 with Trace(
#     105     "receive_response_headers", logger, request, kwargs
#     106 ) as trace:
#     107     (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112         trailing_data,
# --> 113     ) = self._receive_response_headers(**kwargs)
#     114     trace.return_value = (
#     115         http_version,
#     116         status,
#     117         reason_phrase,
#     118         headers,
#     119     )
#     121 network_stream = self._network_stream
#
# File ~/.local/lib/python3.8/site-packages/httpcore/_sync/http11.py:186, in HTTP11Connection._receive_response_headers(self, request)
#     183 timeout = timeouts.get("read", None)
#     185 while True:
# --> 186     event = self._receive_event(timeout=timeout)
#     187     if isinstance(event, h11.Response):
#     188         break
#
# File ~/.local/lib/python3.8/site-packages/httpcore/_sync/http11.py:224, in HTTP11Connection._receive_event(self, timeout)
#     221     event = self._h11_state.next_event()
#     223 if event is h11.NEED_DATA:
# --> 224     data = self._network_stream.read(
#     225         self.READ_NUM_BYTES, timeout=timeout
#     226     )
#     228     # If we feed this case through h11 we'll raise an exception like:
#     229     #
#     230     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     234     # perspective. Instead we handle this case distinctly and treat
#     235     # it as a ConnectError.
#     236     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/.local/lib/python3.8/site-packages/httpcore/_backends/sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
# --> 126     return self._sock.recv(max_bytes)
#
# File /usr/lib/python3.8/ssl.py:1226, in SSLSocket.recv(self, buflen, flags)
#    1222     if flags != 0:
#    1223         raise ValueError(
#    1224             "non-zero flags not allowed in calls to recv() on %s" %
#    1225             self.__class__)
# -> 1226     return self.read(buflen)
#    1227 else:
#    1228     return super().recv(buflen, flags)
#
# File /usr/lib/python3.8/ssl.py:1101, in SSLSocket.read(self, len, buffer)
#    1099         return self._sslobj.read(len, buffer)
#    1100     else:
# -> 1101         return self._sslobj.read(len)
#    1102 except SSLError as x:
#    1103     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %% [markdown]
# #### planning

# %%
planning_summaries = []
for file_name in files:
    if '.json' not in file_name:
        print('File Name:', file_name)
        file_path = path + file_name
        data = load_pickle(file_path)
        data['camera_info'] = camera_info
        env_summary = []
        for i in range(len(data['rgb'])):
            print('Key Frame:', str(i))
            keyframe = {'rgb': data['rgb'][i], 
                        'depth': data['depth'][i], 
                        'odom': data['odom'][i], 
                        'joint_state': data['joint_state'][i], 
                        'state': data['state'][i],
                        'state_history': data['state_history'][i],
                        'camera_info': data['camera_info']}
            
            planning_summary = narr_engine.summarize_planning(keyframe, task_name=task_name, task_desc=task_desc)
            planning_summaries.append(planning_summary)

            # print(planning_summary)
            with open(file_path.replace('.pkl', '_planning_sum.json'), 'w') as f:
                json.dump({'planning_sum': planning_summaries}, f)

# %% [markdown]
# #### Narration (info)

# %%
task_name = 'Pick and place the cup in the sink'
# task_desc = 'The robot should navigate to the table with dirty cup on it, pick up the cup, find the sink, navigate to the sink and place the cup in the sink.'

for file_name in files:
    if '.pkl' in file_name:
        bag_name = file_name.replace('.pkl', '')
        if (bag_name+'_env_sum.json' in files or bag_name+'_env_sum_35_turbo.json' in files) and bag_name+'_internal_sum.json' in files and bag_name+'_planning_sum.json' in files:
            print('File Name:', file_name)
            if bag_name+'_env_sum.json' in files:
                env_summaries = load_json(path+bag_name+'_env_sum.json')['env_sum']
            elif bag_name+'_env_sum_35_turbo.json' in files:
                env_summaries = load_json(path+bag_name+'_env_sum_35_turbo.json')['env_sum']
            internal_summaries = load_json(path+bag_name+'_internal_sum.json')['internal_sum']
            planning_summaries = load_json(path+bag_name+'_planning_sum.json')['planning_sum']
            
            narration_history = []
            for i in range(len(env_summaries)):
                print('Frame # / Timestamp:', i)
                narration = narr_engine.narrate_frame(task, env_summary=env_summaries[i], internal_summary=internal_summaries[i], planning_summary=planning_summaries[i], constrains=None, narration_history=narration_history, mode='info')
                narration_history.append(narration)
                print(narration)
                print('\n')
                # with open(file_path.replace('.pkl', '_narration.json'), 'w') as f:
                #     json.dump({'narration': narration_history}, f)

        break
